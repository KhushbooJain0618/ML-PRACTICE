# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushbooJain0618/ML-PRACTICE/blob/main/ML5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     28.9782
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     30.6647
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     19.5478
# 3  The true story of how businessman Oskar Schind...   1993-12-15     14.1647
# 4  The defense and the prosecution have rested an...   1957-04-10     11.7491
#
#    vote_average  vote_count
# 0         8.714       29584
# 1         8.700       22343
# 2         8.570       13510
# 3         8.566       17022
# 4         8.552        9681

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 6335  339397              Café Society
# 6336    5653                    Luther
# 6337    1825              Over the Top
# 6338     559              Spider-Man 3
# 6339  425001      The War with Grandpa
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 6335  The story of a young man who arrives in Hollyw...   2016-05-11
# 6336  During the early 16th century, idealistic Germ...   2003-10-29
# 6337  Lincoln Hawk a hard-luck big-rig trucker takes...   1987-02-13
# 6338  The seemingly invincible Spider-Man goes up ag...   2007-05-01
# 6339  Peter is thrilled that his Grandpa is coming t...   2020-08-27
#
#       popularity  vote_average  vote_count
# 0        28.9782         8.714       29584
# 1        30.6647         8.700       22343
# 2        19.5478         8.570       13510
# 3        14.1647         8.566       17022
# 4        11.7491         8.552        9681
# ...          ...           ...         ...
# 6335      1.5580         6.447        2771
# 6336      5.0594         6.448         328
# 6337      4.0194         6.446        1811
# 6338     14.4498         6.448       14898
# 6339      2.1683         6.446        1036
#
# [6340 rows x 7 columns]

# %%
df.shape
# Out:
# (6340, 7)

# %%
df.to_csv('movies.csv')
