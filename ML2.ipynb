# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushbooJain0618/ML-PRACTICE/blob/main/ML2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !pip install --user kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d wobotintelligence/face-mask-detection-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/wobotintelligence/face-mask-detection-dataset
# License(s): CC0-1.0
# ...
#  99% 2.48G/2.50G [00:37<00:00, 176MB/s]
# 100% 2.50G/2.50G [00:37<00:00, 71.3MB/s]

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/face-mask-detection-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()
